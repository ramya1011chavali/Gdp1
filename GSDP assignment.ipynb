# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white")
df1 = pd.read_csv(r'C:\Users\chavali\Desktop\assignment/data.csv')
df=df1
df1.head()
#imported the data and loaded to the python
# Out:
#                      Items Description Duration  Andhra Pradesh   \
# 0  GSDP - CONSTANT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CONSTANT PRICES (` in Crore)  2012-13         380629.0
# 2  GSDP - CONSTANT PRICES (` in Crore)  2013-14         407115.0
# 3  GSDP - CONSTANT PRICES (` in Crore)  2014-15         441741.0
# 4  GSDP - CONSTANT PRICES (` in Crore)  2015-16         490134.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            11299.0  147342.0  256851.0      165937.0  35850.0  682650.0
# 2            12348.0  154525.0  269650.0      182229.0  31568.0  734284.0
# 3            13541.0  166709.0  304766.0      196023.0  34611.0  791569.0
# 4            13963.0  179595.0  326535.0      209012.0  37520.0  864314.0
#
#     Haryana  ...  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# ...

# %%
df1.describe()
#checked the mean median and max via describe
# Out:
#        Andhra Pradesh   Arunachal Pradesh          Assam          Bihar  \
# count        12.000000          10.000000       9.000000      10.000000
# mean     220506.696667        6223.821000   87929.074444  140497.507000
# std      234653.888453        6612.238145   84075.321008  149768.577756
# min           0.000000           0.000000       0.000000       0.000000
# 25%           8.122500           4.662500       4.880000       5.520000
# 50%      189706.805000        5536.330000  143175.000000  123578.510000
# 75%      415771.500000       12085.750000  154525.000000  266450.250000
# max      547021.000000       13963.000000  179595.000000  326535.000000
#
#         Chhattisgarh           Goa        Gujarat        Haryana  \
# count      10.000000      9.000000       9.000000      10.000000
# mean   113522.936000  20210.924444  409827.694444  216581.964000
# std     99505.381977  19384.474470  394674.910968  190178.177319
# ...

# %%
df1.isnull().sum(axis=1)
#calculated the null values  present in each row
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4     10
# 5     23
# 6      1
# 7      1
# 8      1
# 9     17
# 10    25
# 11     3
# dtype: int64

# %%
df1=df1.drop([10,11,5])
df1
#dropped the empty row and the rows of year 2016-17 as there are many missing values like 25 and 23 so there is no point of maupulating the data
# Out:
#                      Items Description Duration  Andhra Pradesh   \
# 0  GSDP - CONSTANT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CONSTANT PRICES (` in Crore)  2012-13        380629.00
# 2  GSDP - CONSTANT PRICES (` in Crore)  2013-14        407115.00
# 3  GSDP - CONSTANT PRICES (` in Crore)  2014-15        441741.00
# 4  GSDP - CONSTANT PRICES (` in Crore)  2015-16        490134.00
# 6        (% Growth over previous year)  2012-13             0.32
# 7        (% Growth over previous year)  2013-14             6.96
# 8        (% Growth over previous year)  2014-15             8.51
# 9        (% Growth over previous year)  2015-16            10.96
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           11299.00  147342.00  256851.00     165937.00  35850.00  682650.00
# 2           12348.00  154525.00  269650.00     182229.00  31568.00  734284.00
# ...

# %%
gdp=df1.drop([0,1,2,3,4])
gdp
#dropped the GDPas for the 1st Question we only need to growth rate
# Out:
#                Items Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 6  (% Growth over previous year)  2012-13             0.32               2.14
# 7  (% Growth over previous year)  2013-14             6.96               9.29
# 8  (% Growth over previous year)  2014-15             8.51               9.66
# 9  (% Growth over previous year)  2015-16            10.96               3.12
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  ...  Telangana  \
# 6   2.91   3.93          4.97 -15.38    10.89     7.74  ...       2.74
# 7   4.88   4.98          9.82 -11.94     7.56     8.18  ...       5.58
# 8   7.88  13.02          7.57   9.64     7.80     5.72  ...       8.74
# 9    NaN   7.14           NaN    NaN      NaN      NaN  ...       9.53
#
#    Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 6     8.67           4.26         7.24           NaN
# 7     9.32           6.40         8.23           NaN
# 8     9.94           6.30         5.00           NaN
# ...

# %%
gdp=gdp.set_index('Items Description')
gdp
#set the items as index
# Out:
#                               Duration  Andhra Pradesh   Arunachal Pradesh  \
# Items Description
# (% Growth over previous year)  2012-13             0.32               2.14
# (% Growth over previous year)  2013-14             6.96               9.29
# (% Growth over previous year)  2014-15             8.51               9.66
# (% Growth over previous year)  2015-16            10.96               3.12
#
#                                Assam  Bihar  Chhattisgarh    Goa  Gujarat  \
# Items Description
# (% Growth over previous year)   2.91   3.93          4.97 -15.38    10.89
# (% Growth over previous year)   4.88   4.98          9.82 -11.94     7.56
# (% Growth over previous year)   7.88  13.02          7.57   9.64     7.80
# (% Growth over previous year)    NaN   7.14           NaN    NaN      NaN
#
#                                Haryana  Himachal Pradesh  ...  Telangana  \
# Items Description                                         ...
# ...

# %%
gdp1=gdp.transpose()
gdp1
# Out:
# Items Description         (% Growth over previous year)  \
# Duration                                        2012-13
# Andhra Pradesh                                     0.32
# Arunachal Pradesh                                  2.14
# Assam                                              2.91
# Bihar                                              3.93
# Chhattisgarh                                       4.97
# Goa                                              -15.38
# Gujarat                                           10.89
# Haryana                                            7.74
# Himachal Pradesh                                   6.41
# Jammu & Kashmir                                    2.89
# Jharkhand                                          8.17
# Karnataka                                           6.2
# Kerala                                              6.5
# Madhya Pradesh                                    11.38
# Maharashtra                                        6.61
# ...

# %%
gdp1=gdp1.drop(['West Bengal1','Delhi','Chandigarh','Andaman & Nicobar Islands','Puducherry'])
gdp1
#droped the union territories as only states are required and for west bengal there is no data provided
# Out:
# Items Description (% Growth over previous year) (% Growth over previous year)  \
# Duration                                2012-13                       2013-14
# Andhra Pradesh                             0.32                          6.96
# Arunachal Pradesh                          2.14                          9.29
# Assam                                      2.91                          4.88
# Bihar                                      3.93                          4.98
# Chhattisgarh                               4.97                          9.82
# Goa                                      -15.38                        -11.94
# Gujarat                                   10.89                          7.56
# Haryana                                    7.74                          8.18
# Himachal Pradesh                           6.41                          7.06
# Jammu & Kashmir                            2.89                          6.23
# ...

# %%
gdp2=gdp1.transpose()
gdp2
# Out:
#                               Duration Andhra Pradesh  Arunachal Pradesh  \
# Items Description
# (% Growth over previous year)  2012-13            0.32              2.14
# (% Growth over previous year)  2013-14            6.96              9.29
# (% Growth over previous year)  2014-15            8.51              9.66
# (% Growth over previous year)  2015-16           10.96              3.12
#
#                               Assam  Bihar Chhattisgarh    Goa Gujarat  \
# Items Description
# (% Growth over previous year)  2.91   3.93         4.97 -15.38   10.89
# (% Growth over previous year)  4.88   4.98         9.82 -11.94    7.56
# (% Growth over previous year)  7.88  13.02         7.57   9.64     7.8
# (% Growth over previous year)   NaN   7.14          NaN    NaN     NaN
#
#                               Haryana Himachal Pradesh  ... Odisha Punjab  \
# Items Description                                       ...
# ...

# %%
gdp2['Year']=gdp2['Duration'].str[:4]
gdp2["Year"]=gdp2['Year'].apply(lambda x: round(int(x),0))
gdp2
#extracted the year from duration as for the scatter or reg plot you can only plot between float and int but not with a object so converted duration to int/year
# Out:
#                               Duration Andhra Pradesh  Arunachal Pradesh  \
# Items Description
# (% Growth over previous year)  2012-13            0.32              2.14
# (% Growth over previous year)  2013-14            6.96              9.29
# (% Growth over previous year)  2014-15            8.51              9.66
# (% Growth over previous year)  2015-16           10.96              3.12
#
#                               Assam  Bihar Chhattisgarh    Goa Gujarat  \
# Items Description
# (% Growth over previous year)  2.91   3.93         4.97 -15.38   10.89
# (% Growth over previous year)  4.88   4.98         9.82 -11.94    7.56
# (% Growth over previous year)  7.88  13.02         7.57   9.64     7.8
# (% Growth over previous year)   NaN   7.14          NaN    NaN     NaN
#
#                               Haryana Himachal Pradesh  ... Punjab Rajasthan  \
# Items Description                                       ...
# ...

# %%
sns.regplot(x='Year', y='Sikkim', data=gdp2)
#the REg plot for the Sikkim which has slight growth but it increased first and decreased

# %%
sns.regplot(x='Year', y='Andhra Pradesh ', data=gdp2)
#this is the plot for my hometown where the growth rate was high at 2013 but decreased in 2014 and then increased overall there is a slight growth

# %%
#this the regplot for each state and all the states
for i in gdp2.columns[1:-1]:
    sns.regplot(x='Year', y=i, data=gdp2)
    plt.show()

# %%
gdp3=gdp2.T
gdp3.drop(['Year'])
gdp4=gdp3.T
gdp4=gdp4.set_index('Duration')
states=gdp2.columns[1:-1]
states
gdp5=gdp4.T
gdp5
#dropped the Year and taking mean would be a Issue
# Out:
# Duration          2012-13 2013-14 2014-15 2015-16
# Andhra Pradesh       0.32    6.96    8.51   10.96
# Arunachal Pradesh    2.14    9.29    9.66    3.12
# Assam                2.91    4.88    7.88     NaN
# Bihar                3.93    4.98   13.02    7.14
# Chhattisgarh         4.97    9.82    7.57     NaN
# Goa                -15.38  -11.94    9.64     NaN
# Gujarat             10.89    7.56     7.8     NaN
# Haryana              7.74    8.18    5.72     NaN
# Himachal Pradesh     6.41    7.06    7.47     NaN
# Jammu & Kashmir      2.89    6.23   -0.31     NaN
# Jharkhand            8.17    1.57   12.47   12.14
# Karnataka             6.2   10.51    7.29    7.27
# Kerala                6.5    3.89    7.31     NaN
# Madhya Pradesh      11.38    3.62    5.44    7.97
# Maharashtra          6.61    6.24    5.76     NaN
# Manipur              0.54    8.71    6.48     NaN
# Meghalaya            2.19    1.83    2.06    6.41
# Mizoram              7.15   16.21    6.59     NaN
# ...

# %%
gdp5['mean'] = gdp5.mean(axis=1)
gdp5
#Took mean for the all the years
# Out:
# Duration          2012-13 2013-14 2014-15 2015-16         mean
# Andhra Pradesh       0.32    6.96    8.51   10.96     6.687500
# Arunachal Pradesh    2.14    9.29    9.66    3.12     6.052500
# Assam                2.91    4.88    7.88     NaN     5.223333
# Bihar                3.93    4.98   13.02    7.14     7.267500
# Chhattisgarh         4.97    9.82    7.57     NaN     7.453333
# Goa                -15.38  -11.94    9.64     NaN    -5.893333
# Gujarat             10.89    7.56     7.8     NaN     8.750000
# Haryana              7.74    8.18    5.72     NaN     7.213333
# Himachal Pradesh     6.41    7.06    7.47     NaN     6.980000
# Jammu & Kashmir      2.89    6.23   -0.31     NaN     2.936667
# Jharkhand            8.17    1.57   12.47   12.14     8.587500
# Karnataka             6.2   10.51    7.29    7.27     7.817500
# Kerala                6.5    3.89    7.31     NaN     5.900000
# Madhya Pradesh      11.38    3.62    5.44    7.97     7.102500
# ...

# %%
gdp5.sort_values(by=['mean'],inplace=True,ascending=True)
gdp5
#performed sort to identify the max and min mean values
# Out:
# Duration          2012-13 2013-14 2014-15 2015-16         mean
# Goa                -15.38  -11.94    9.64     NaN    -5.893333
# Jammu & Kashmir      2.89    6.23   -0.31     NaN     2.936667
# Meghalaya            2.19    1.83    2.06    6.41     3.122500
# Assam                2.91    4.88    7.88     NaN     5.223333
# Manipur              0.54    8.71    6.48     NaN     5.243333
# Sikkim               2.29    6.07    6.34    6.51     5.302500
# Rajasthan            4.24    6.07    6.11     NaN     5.473333
# Punjab               5.32    6.32    4.92     NaN     5.520000
# Kerala                6.5    3.89    7.31     NaN     5.900000
# Uttar Pradesh        4.26     6.4     6.3    7.13     6.022500
# Arunachal Pradesh    2.14    9.29    9.66    3.12     6.052500
# Nagaland             5.09   11.13    2.09     NaN     6.103333
# Maharashtra          6.61    6.24    5.76     NaN     6.203333
# Odisha               4.61    8.73       6    6.01     6.337500
# ...

# %%
plt.figure(figsize=(50,10))
plt.hist(states,gdp5['mean'])
plt.show()
#plotted the graph for average

# %%
gsdp=df1.loc[4]
gsdp1=gsdp.drop(['West Bengal1','Delhi','Chandigarh','Andaman & Nicobar Islands','Puducherry','All_India GDP'])
gsdp1
#extracted the GSDP for the year 2015 to 2016 and filtered the Union teritories
# Out:
# Items Description    GSDP - CONSTANT PRICES (` in Crore)
# Duration                                         2015-16
# Andhra Pradesh                                    490134
# Arunachal Pradesh                                  13963
# Assam                                             179595
# Bihar                                             326535
# Chhattisgarh                                      209012
# Goa                                                37520
# Gujarat                                           864314
# Haryana                                           399646
# Himachal Pradesh                                     NaN
# Jammu & Kashmir                                    95965
# Jharkhand                                         209137
# Karnataka                                         815545
# Kerala                                            467243
# Madhya Pradesh                                    414607
# ...

# %%
gsdp1.isnull()
#Checked for the NUll values
# Out:
# Items Description    False
# Duration             False
# Andhra Pradesh       False
# Arunachal Pradesh    False
# Assam                False
# Bihar                False
# Chhattisgarh         False
# Goa                  False
# Gujarat              False
# Haryana              False
# Himachal Pradesh      True
# Jammu & Kashmir      False
# Jharkhand            False
# Karnataka            False
# Kerala               False
# Madhya Pradesh       False
# Maharashtra           True
# Manipur               True
# Meghalaya            False
# Mizoram               True
# Nagaland              True
# Odisha               False
# Punjab                True
# Rajasthan             True
# Sikkim               False
# Tamil Nadu           False
# Telangana            False
# Tripura               True
# Uttar Pradesh        False
# Uttarakhand          False
# Name: 4, dtype: bool

# %%
gsdp1.drop(['Himachal Pradesh','Maharashtra','Manipur','Mizoram','Nagaland','Punjab','Rajasthan','Tripura'])
#Removed all the NUll values
# Out:
# Items Description    GSDP - CONSTANT PRICES (` in Crore)
# Duration                                         2015-16
# Andhra Pradesh                                    490134
# Arunachal Pradesh                                  13963
# Assam                                             179595
# Bihar                                             326535
# Chhattisgarh                                      209012
# Goa                                                37520
# Gujarat                                           864314
# Haryana                                           399646
# Jammu & Kashmir                                    95965
# Jharkhand                                         209137
# Karnataka                                         815545
# Kerala                                            467243
# Madhya Pradesh                                    414607
# Meghalaya                                          22507
# ...

# %%
# %matplotlib inline
import glob
path=r'C:\Users\chavali\Desktop\assignment\data1b'
all_files=glob.glob(path+'/*.csv')
all_files[0].split('\\')[-1].split('-')[1].replace('_',' ')
#checked if it working for 1 dataframe first and wrote a logic for all
# Out:
# 'Andhra Pradesh'

# %%
li= []
for file in all_files:
    df=pd.read_csv(file,encoding = 'ISO-8859-1')
    df=df[['Item','2014-15']]
    df=df.T
    df.columns=df.iloc[0]
    df=df[1:]
    df['State']=file.split('\\')[-1].split('-')[1].replace('_',' ')
    li.append(df)
#Gathered all the data from different files and made into one dataframe

# %%
g2=pd.concat(li, axis=0, ignore_index=True,sort=False)
g2
# merged the list into a dataframe
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 0                           14819416      7893514      4309078
# 1                             686117       415520        38387
# 2                            3855548      2890544       173478
# 3                            7951890      4688237      2060296
# 4                              16233         1659        13992
# 5                            3948847      2613371       352208
# 6                             250568        64959       183770
# 7                             308507       140421        30141
# 8                          1.377e+07  9.67109e+06  2.69891e+06
# 9                        8.01524e+06  4.63673e+06  2.91617e+06
# 10                           1514981       853758       110304
# 11                           3211065      2094466       562503
# 12                          11219422      8157179      1868771
# 13                           5930617      3070386      1656104
# ...

# %%
gu=g2['State'].isin(['Chandigarh','Delhi','Puducherry'])
gf=g2.loc[~gu]
gf4=gf
gf
#Filtered the Union Territores
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 0                           14819416      7893514      4309078
# 1                             686117       415520        38387
# 2                            3855548      2890544       173478
# 3                            7951890      4688237      2060296
# 5                            3948847      2613371       352208
# 7                             308507       140421        30141
# 8                          1.377e+07  9.67109e+06  2.69891e+06
# 9                        8.01524e+06  4.63673e+06  2.91617e+06
# 10                           1514981       853758       110304
# 11                           3211065      2094466       562503
# 12                          11219422      8157179      1868771
# 13                           5930617      3070386      1656104
# 14                          16235647     13216013      1932769
# 15                          16475655     10435121      3972829
# ...

# %%
gf2=gf.sort_values(by=['Per Capita GSDP (Rs.)'],ascending=True)
gf3=gf2
gf
#sorted the GDP per capita in ascending order to know top 5 and the bottom 5 states based on the GDP per capita.

# %%
plt.figure(figsize=(100,20))
sns.catplot(x='State', y='Per Capita GSDP (Rs.)', kind="bar", data=gf2)
#ploted the Graph 
#the top 5 are Goa, Sikkim, Haryana, Kerla, Uttharakand
#Bottom 5 states are Bihar,Uttar Pradesh,Manipur, Assam, Jharkhand
#Goa/ Sikkim= 8.004741709371503

# %%
gf2['pcp']=(gf2['Primary']/gf2['Gross State Domestic Product'])*100
gf2['pcp']=gf2['pcp'].apply(lambda x: round(x,2))
gf2
#calculated the Percentage contribution of primary sector with the GSDP
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 3                            7951890      4688237      2060296
# 29                          25097754     16215212      7096876
# 16                            383140       226583        75483
# 2                            3855548      2890544       173478
# 11                           3211065      2094466       562503
# 14                          16235647     13216013      1932769
# 20                           6422978      4382636       788243
# 17                            366521       223330        72442
# 27                            799825       397591        88176
# 23                          15044394      7673441      5356257
# 5                            3948847      2613371       352208
# 19                            607897       375825       123800
# 18                            217010       116609        45590
# 0                           14819416      7893514      4309078
# ...

# %%
gf2['scp']=(gf2['Secondary']/gf2['Gross State Domestic Product'])*100
gf2['scp']=gf2['scp'].apply(lambda x: round(x,2))
gf2
#calculated the Percentage contribution of Secondary sector with the GSDP
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 3                            7951890      4688237      2060296
# 29                          25097754     16215212      7096876
# 16                            383140       226583        75483
# 2                            3855548      2890544       173478
# 11                           3211065      2094466       562503
# 14                          16235647     13216013      1932769
# 20                           6422978      4382636       788243
# 17                            366521       223330        72442
# 27                            799825       397591        88176
# 23                          15044394      7673441      5356257
# 5                            3948847      2613371       352208
# 19                            607897       375825       123800
# 18                            217010       116609        45590
# 0                           14819416      7893514      4309078
# ...

# %%
gf2['tcp']=(gf2['Tertiary']/gf2['Gross State Domestic Product'])*100
gf2['tcp']=gf2['tcp'].apply(lambda x: round(x,2))
gf2
#calculated the Percentage contribution of tertiary sector with the GSDP
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 3                            7951890      4688237      2060296
# 29                          25097754     16215212      7096876
# 16                            383140       226583        75483
# 2                            3855548      2890544       173478
# 11                           3211065      2094466       562503
# 14                          16235647     13216013      1932769
# 20                           6422978      4382636       788243
# 17                            366521       223330        72442
# 27                            799825       397591        88176
# 23                          15044394      7673441      5356257
# 5                            3948847      2613371       352208
# 19                            607897       375825       123800
# 18                            217010       116609        45590
# 0                           14819416      7893514      4309078
# ...

# %%
plt.figure(figsize=(200,50))
sns.catplot(x='State', y='pcp', kind="bar", data=gf2)
#ploted the graph of %contribution of primary sector with All states and this bar plot

# %%
plt.figure(figsize=(200,50))
sns.catplot(x='State', y='scp', kind="bar", data=gf2)
#ploted the graph of %contribution of primary sector with All states and this bar plot

# %%
plt.figure(figsize=(200,50))
sns.catplot(x='State', y='tcp', kind="bar", data=gf2)
#ploted the graph of %contribution of primary sector with All states and this bar plot

# %%
gf2.plot(x="State", y=["pcp", "scp", "tcp"], kind="bar")

# %%
gf2['Percentile_rank']=gf2['Per Capita GSDP (Rs.)'].rank(pct=True)
gf2['Percentile_rank']=gf2['Percentile_rank'].apply(lambda x: round(x,2))
gf2
#calculated the percentage Rank for Per Capita GSDP
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 3                            7951890      4688237      2060296
# 29                          25097754     16215212      7096876
# 16                            383140       226583        75483
# 2                            3855548      2890544       173478
# 11                           3211065      2094466       562503
# 14                          16235647     13216013      1932769
# 20                           6422978      4382636       788243
# 17                            366521       223330        72442
# 27                            799825       397591        88176
# 23                          15044394      7673441      5356257
# 5                            3948847      2613371       352208
# 19                            607897       375825       123800
# 18                            217010       116609        45590
# 0                           14819416      7893514      4309078
# ...

# %%
gf2['pcp'].corr(gf2['Percentile_rank'])
#correlation between percentage rank and the primary sector contribution
# Out:
# -0.6194694978393281

# %%
c4=gf3['Per Capita GSDP (Rs.)'].quantile(0.2)
c3=gf3['Per Capita GSDP (Rs.)'].quantile(0.5)
c2=gf3['Per Capita GSDP (Rs.)'].quantile(0.85)
c1=gf3['Per Capita GSDP (Rs.)'].quantile(1)
#calculated the Quantile

# %%
def cond(gf3):
    if(gf3['Per Capita GSDP (Rs.)']<=c1 and gf3['Per Capita GSDP (Rs.)']>=c2):
        return 'C1'
    elif(gf3['Per Capita GSDP (Rs.)']<=c2 and gf3['Per Capita GSDP (Rs.)']>=c3):
        return 'C2'
    elif(gf3['Per Capita GSDP (Rs.)']<=c3 and gf3['Per Capita GSDP (Rs.)']>=c4):
        return 'C3'
    elif(gf3['Per Capita GSDP (Rs.)']<=c4):
        return 'C4'
    else:
        return 0
gf3['Quan_cat']=gf3.apply(cond,axis=1)
gf3
#Categorized into c1 to c4 with a Function
# Out:
#    Agriculture, forestry and fishing        Crops    Livestock  \
# 3                            7951890      4688237      2060296
# 29                          25097754     16215212      7096876
# 16                            383140       226583        75483
# 2                            3855548      2890544       173478
# 11                           3211065      2094466       562503
# 14                          16235647     13216013      1932769
# 20                           6422978      4382636       788243
# 17                            366521       223330        72442
# 27                            799825       397591        88176
# 23                          15044394      7673441      5356257
# 5                            3948847      2613371       352208
# 19                            607897       375825       123800
# 18                            217010       116609        45590
# 0                           14819416      7893514      4309078
# ...

# %%
c1df=gf3[gf3.Quan_cat=='C1']
c2df=gf3[gf3.Quan_cat=='C2']
c3df=gf3[gf3.Quan_cat=='C3']
c4df=gf3[gf3.Quan_cat=='C4']
#categoried the values

# %%
#grouping the Category
cat1=gf3.groupby(['Quan_cat']).sum()
cat1
# Out:
#           Agriculture, forestry and fishing       Crops   Livestock  \
# Quan_cat
# C1                               14391809.0   7962514.0   4619756.0
# C2                               90028438.0  55443609.0  23672969.0
# C3                               27407472.0  15782803.0   6826716.0
# C4                               56735044.0  39331055.0  11901405.0
#
#           Forestry and logging  Fishing and aquaculture  Mining and quarrying  \
# Quan_cat
# C1                    872335.0                 937204.0              588961.0
# C2                   5949373.0                4962486.0            11857646.0
# C3                   3699735.0                1098217.0             9351471.0
# C4                   3673623.0                1828960.0             6096419.0
#
#               Primary  Manufacturing  \
# Quan_cat
# C1         14980771.0     13758793.0
# C2        101886085.0    113868796.0
# C3         36758945.0     17366065.0
# C4         62831463.0     24987032.0
#
# ...

# %%
cat1.drop(columns=['Primary','Crops','Livestock','Forestry and logging','Fishing and aquaculture','Trade & repair services','Hotels & restaurants','Railways','Road transport','Water transport','Air transport','Services incidental to transport','Storage','Communication & services related to broadcasting','Secondary','Tertiary',
       'TOTAL GSVA at basic prices', 'Taxes on Products',
       'Subsidies on products'],axis=1,inplace=True)

# %%
cat1
# Out:
#           Agriculture, forestry and fishing  Mining and quarrying  \
# Quan_cat
# C1                               14391809.0              588961.0
# C2                               90028438.0            11857646.0
# C3                               27407472.0             9351471.0
# C4                               56735044.0             6096419.0
#
#           Manufacturing  \
# Quan_cat
# C1           13758793.0
# C2          113868796.0
# C3           17366065.0
# C4           24987032.0
#
#           Electricity, gas, water supply & other utility services  \
# Quan_cat
# C1                                                2000998.0
# C2                                               14975107.0
# C3                                                3453045.0
# C4                                                4310264.0
#
#           Construction  Trade, repair, hotels and restaurants  \
# Quan_cat
# C1          11264451.0                             13995159.0
# ...

# %%
cat1.drop(columns=['Per Capita GSDP (Rs.)','Services incidental to transport*','Trade & repair services*','Road transport**','Road transport*'],axis=1,inplace=True)

# %%
cat1.drop(columns=['State'],axis=1,inplace=True)
cat1
#this error is because i have this twice and it showing the error as it is already dropped
# Out:
#           Agriculture, forestry and fishing  Mining and quarrying  \
# Quan_cat
# C1                               14391809.0              588961.0
# C2                               90028438.0            11857646.0
# C3                               27407472.0             9351471.0
# C4                               56735044.0             6096419.0
#
#           Manufacturing  \
# Quan_cat
# C1           13758793.0
# C2          113868796.0
# C3           17366065.0
# C4           24987032.0
#
#           Electricity, gas, water supply & other utility services  \
# Quan_cat
# C1                                                2000998.0
# C2                                               14975107.0
# C3                                                3453045.0
# C4                                                4310264.0
#
#           Construction  Trade, repair, hotels and restaurants  \
# Quan_cat
# C1          11264451.0                             13995159.0
# ...

# %%
catli=[]
for ct in list(cat1.index):
    cat2=cat1.T[ct]
    cat2=cat2.reset_index()
    cat2.rename(columns={ct:'Values','index':'Items'},inplace=True)
    cat2=cat2.sort_values(by='Values',ascending=False)
    cat2=cat2.reset_index(drop=True)
    category_gsdp_val=list(cat2['Values'])[0]
    def get_contri_percent(x):
        ret_val=round(100*(x/category_gsdp_val),2)
        return ret_val
    cat2['%Contri in GDP']=cat2['Values'].apply(get_contri_percent)
    end=4
    while cat2.loc[1:end,'%Contri in GDP'].sum()<79:
        end=end+1
    cat2=cat2.loc[1:end]
    catli.append(cat2)
#calculated the subsectors percentage upto 80%

# %%
#plotting contri to sectors having approx.80% contri to gsdp to different states categories
figure=plt.figure(figsize=(10,15))
for index in range (len(catli)):
    plt.subplot(4,1,index+1)
    ax=sns.barplot(x=catli[index]['%Contri in GDP'],y=catli[index]['Items'],data=catli[index])
    plt.xlabel('')
    plt.ylabel('ct:'+str(index+1),fontsize=14)
    plt.yticks(fontsize=12)
    plt.xticks(np.arange(0,25,3),fontsize=10)
    plt.xlim(0,25)
plt.xlabel('%Contribution of items in GSDP',fontsize=16)
plt.show()

# %%
# %matplotlib inline 
da=pd.read_csv(r'C:\Users\chavali\Desktop\assignment/rs_session243_au570_1.1.csv')
da.head()
#loaded the data
# Out:
#   Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0       1              A & N Islands                 0.68
# 1       2             Andhra Pradesh                 3.18
# 2       3          Arunachal Pradesh                15.16
# 3       4                      Assam                 6.24
# 4       5                      Bihar                  NaN
#
#    Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                 1.21                   0.51                       1.23
# 1                 4.35                   6.72                       3.36
# 2                10.89                  10.82                       7.47
# 3                 7.44                  15.36                       7.20
# 4                 2.09                    NaN                        NaN
#
#    Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                       0.51                       1.69
# 1                       3.78                       5.20
# ...

# %%
da.drop(columns=['Primary - 2012-2013','Primary - 2014-2015','Upper Primary - 2012-2013','Upper Primary - 2013-2014','Secondary - 2012-2013','Secondary - 2013-2014','Senior Secondary - 2012-2013','Senior Secondary - 2013-2014'],axis=1,inplace=True)
#droped the unnecessary columns

# %%
da.drop(columns=['Sl. No.'],axis=1,inplace=True)

# %%
da
# Out:
#    Level of Education - State  Primary - 2014-2015.1  \
# 0               A & N Islands                   0.51
# 1              Andhra Pradesh                   6.72
# 2           Arunachal Pradesh                  10.82
# 3                       Assam                  15.36
# 4                       Bihar                    NaN
# 5                  Chandigarh                    NaN
# 6                 Chhatisgarh                   2.91
# 7        Dadra & Nagar Haveli                   1.47
# 8                 Daman & Diu                   1.11
# 9                       Delhi                    NaN
# 10                        Goa                   0.73
# 11                    Gujarat                   0.89
# 12                    Haryana                   5.61
# 13           Himachal Pradesh                   0.64
# 14          Jammu and Kashmir                   6.79
# 15                  Jharkhand                   5.48
# 16                  Karnataka                   2.02
# ...

# %%
da1=da.rename(columns={"Level of Education - State": "State", "Primary - 2014-2015.1": "Primary - 2014-2015"})
da1
#Changed the columns name to merge
# Out:
#                    State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0          A & N Islands                 0.51                       1.69
# 1         Andhra Pradesh                 6.72                       5.20
# 2      Arunachal Pradesh                10.82                       6.71
# 3                  Assam                15.36                      10.51
# 4                  Bihar                  NaN                       4.08
# 5             Chandigarh                  NaN                       0.44
# 6            Chhatisgarh                 2.91                       5.85
# 7   Dadra & Nagar Haveli                 1.47                       4.02
# 8            Daman & Diu                 1.11                       3.11
# 9                  Delhi                  NaN                       0.76
# 10                   Goa                 0.73                       0.07
# 11               Gujarat                 0.89                       6.41
# ...

# %%
da1.State
# Out:
# 0            A & N Islands
# 1           Andhra Pradesh
# 2        Arunachal Pradesh
# 3                    Assam
# 4                    Bihar
# 5               Chandigarh
# 6              Chhatisgarh
# 7     Dadra & Nagar Haveli
# 8              Daman & Diu
# 9                    Delhi
# 10                     Goa
# 11                 Gujarat
# 12                 Haryana
# 13        Himachal Pradesh
# 14       Jammu and Kashmir
# 15               Jharkhand
# 16               Karnataka
# 17                  Kerala
# 18             Lakshadweep
# 19          Madhya Pradesh
# 20             Maharashtra
# 21                 Manipur
# 22               Meghalaya
# 23                 Mizoram
# 24                Nagaland
# 25                  Odisha
# 26              Puducherry
# 27                  Punjab
# 28               Rajasthan
# 29                  Sikkim
# 30              Tamil Nadu
# 31               Telangana
# 32                 Tripura
# 33           Uttar Pradesh
# ...

# %%
gf2.drop(columns=['Agriculture, forestry and fishing', 'Crops', 'Livestock',
       'Forestry and logging', 'Fishing and aquaculture',
       'Mining and quarrying', 'Primary', 'Manufacturing',
       'Electricity, gas, water supply & other utility services',
       'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
       'Trade & repair services', 'Hotels & restaurants',
       'Transport, storage, communication & services related to broadcasting',
       'Railways', 'Road transport', 'Water transport', 'Air transport',
       'Services incidental to transport', 'Storage',
       'Communication & services related to broadcasting',
       'Financial services',
       'Real estate, ownership of dwelling & professional services',
       'Public administration', 'Other services', 'Tertiary',
       'TOTAL GSVA at basic prices', 'Taxes on Products',
       'Subsidies on products','Services incidental to transport*', 'Trade & repair services*',
       'Road transport**', 'Road transport*', 'Quan_cat','Percentile_rank'],axis=1,inplace=True)
gf2
#removed the unnecessary columns run this command again after droping the values hence it is showing a error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-652-d8477d002f91> in <module>
#      14        'TOTAL GSVA at basic prices', 'Taxes on Products',
#      15        'Subsidies on products','Services incidental to transport*', 'Trade & repair services*',
# ---> 16        'Road transport**', 'Road transport*', 'Quan_cat','Percentile_rank'],axis=1,inplace=True)
#      17 gf2
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
gf2
# Out:
#    Gross State Domestic Product Population ('00) Per Capita GSDP (Rs.)  \
# 3                      37391988          1101240                 33954
# 29                    104337115          2109940                 49450
# 16                  1.80428e+06            30873                 58442
# 2                      19809800           326780                 60621
# 11                     21710718           349660                 62091
# 14                     48198169           765180                 62989
# 20                     32197092           435220                 73979
# 17                  2.44081e+06            32020                 76228
# 27                  2.96666e+06            38350                 77358
# 23                     61219447           721610                 84837
# 5                      23498180           270530                 86860
# 19                      1841424            20550                 89607
# ...

# %%
gf5=gf2
gf5
# Out:
#    Gross State Domestic Product Population ('00) Per Capita GSDP (Rs.)  \
# 3                      37391988          1101240                 33954
# 29                    104337115          2109940                 49450
# 16                  1.80428e+06            30873                 58442
# 2                      19809800           326780                 60621
# 11                     21710718           349660                 62091
# 14                     48198169           765180                 62989
# 20                     32197092           435220                 73979
# 17                  2.44081e+06            32020                 76228
# 27                  2.96666e+06            38350                 77358
# 23                     61219447           721610                 84837
# 5                      23498180           270530                 86860
# 19                      1841424            20550                 89607
# ...

# %%
gf5['State']
# Out:
# 3                 Bihar
# 29        Uttar Pradesh
# 16              Manipur
# 2                 Assam
# 11            Jharkhand
# 14       Madhya Pradesh
# 20               Odisha
# 17            Meghalaya
# 27              Tripura
# 23            Rajasthan
# 5          Chhattisgarh
# 19             Nagaland
# 18              Mizoram
# 0        Andhra Pradesh
# 1     Arunachal Pradesh
# 22               Punjab
# 26            Telangana
# 8               Gujarat
# 12            Karnataka
# 25           Tamil Nadu
# 10     Himachal Pradesh
# 15          Maharashtra
# 28          Uttarakhand
# 13               Kerala
# 9               Haryana
# 24               Sikkim
# 7                   Goa
# Name: State, dtype: object

# %%
ma=pd.merge(da1, gf5, how='inner', on='State')
ma.head()
#merged the data
# Out:
#                State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0     Andhra Pradesh                 6.72                       5.20
# 1  Arunachal Pradesh                10.82                       6.71
# 2              Assam                15.36                      10.51
# 3              Bihar                  NaN                       4.08
# 4                Goa                 0.73                       0.07
#
#    Secondary - 2014-2015  Senior Secondary - 2014-2015  \
# 0                  15.71                           NaN
# 1                  17.11                         18.42
# 2                  27.06                           NaN
# 3                  25.90                           NaN
# 4                  11.15                         13.91
#
#   Gross State Domestic Product Population ('00) Per Capita GSDP (Rs.)    pcp  \
# 0                     52646842           501510                104977  30.97
# ...

# %%
ma1=ma

# %%
ma1.drop(columns=['Gross State Domestic Product',"Population ('00)",'pcp','tcp','scp'],axis=1,inplace=True)
#droped the column due to corelation 
run the command hence showing the error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-677-196aa34f8165> in <module>
# ----> 1 ma1.drop(columns=['Gross State Domestic Product',"Population ('00)",'pcp','tcp','scp'],axis=1,inplace=True)
#       2 ma1.set_index('State')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
ma1.set_index('State')
ma1.corr()
#set the index  State and formed correaltion but there is no corellation with Per Capita GSDP
# Out:
#                               Primary - 2014-2015  Upper Primary - 2014-2015  \
# Primary - 2014-2015                      1.000000                   0.648542
# Upper Primary - 2014-2015                0.648542                   1.000000
# Secondary - 2014-2015                    0.167977                   0.515896
# Senior Secondary - 2014-2015             0.197693                  -0.017727
#
#                               Secondary - 2014-2015  \
# Primary - 2014-2015                        0.167977
# Upper Primary - 2014-2015                  0.515896
# Secondary - 2014-2015                      1.000000
# Senior Secondary - 2014-2015               0.057907
#
#                               Senior Secondary - 2014-2015
# Primary - 2014-2015                               0.197693
# Upper Primary - 2014-2015                        -0.017727
# Secondary - 2014-2015                             0.057907
# Senior Secondary - 2014-2015                      1.000000

# %%
plt.matshow(ma1.corr())
f = plt.figure(figsize=(29, 25))
plt.matshow(ma1.corr(), fignum=f.number)
plt.xticks(range(ma1.shape[1]), ma1.columns, fontsize=18, rotation=45)
plt.yticks(range(ma1.shape[1]), ma1.columns, fontsize=18)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=18)
plt.title('Correlation Matrix of per captia', fontsize=16);

# %%
ma
# Out:
#                 State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      Andhra Pradesh                 6.72                       5.20
# 1   Arunachal Pradesh                10.82                       6.71
# 2               Assam                15.36                      10.51
# 3               Bihar                  NaN                       4.08
# 4                 Goa                 0.73                       0.07
# 5             Gujarat                 0.89                       6.41
# 6             Haryana                 5.61                       5.81
# 7    Himachal Pradesh                 0.64                       0.87
# 8           Jharkhand                 5.48                       8.99
# 9           Karnataka                 2.02                       3.85
# 10             Kerala                  NaN                        NaN
# 11     Madhya Pradesh                 6.59                       9.20
# ...

# %%
ma2=ma
ma3=ma

# %%
ma2.drop(columns=["Population ('00)","Per Capita GSDP (Rs.)"],axis=1,inplace=True)
ma2.set_index('State')
# Out:
#                    Primary - 2014-2015  Upper Primary - 2014-2015  \
# State
# Andhra Pradesh                    6.72                       5.20
# Arunachal Pradesh                10.82                       6.71
# Assam                            15.36                      10.51
# Bihar                              NaN                       4.08
# Goa                               0.73                       0.07
# Gujarat                           0.89                       6.41
# Haryana                           5.61                       5.81
# Himachal Pradesh                  0.64                       0.87
# Jharkhand                         5.48                       8.99
# Karnataka                         2.02                       3.85
# Kerala                             NaN                        NaN
# Madhya Pradesh                    6.59                       9.20
# Maharashtra                       1.26                       1.79
# ...

# %%
ma2.corr()
# Out:
#                               Primary - 2014-2015  Upper Primary - 2014-2015  \
# Primary - 2014-2015                      1.000000                   0.648542
# Upper Primary - 2014-2015                0.648542                   1.000000
# Secondary - 2014-2015                    0.167977                   0.515896
# Senior Secondary - 2014-2015             0.197693                  -0.017727
# pcp                                      0.454750                   0.534988
# tcp                                      0.221495                  -0.088942
# scp                                     -0.447588                  -0.357437
#
#                               Secondary - 2014-2015  \
# Primary - 2014-2015                        0.167977
# Upper Primary - 2014-2015                  0.515896
# Secondary - 2014-2015                      1.000000
# Senior Secondary - 2014-2015               0.057907
# pcp                                        0.335504
# ...

# %%
plt.matshow(ma2.corr())
f = plt.figure(figsize=(29, 25))
plt.matshow(ma2.corr(), fignum=f.number)
plt.xticks(range(ma2.shape[1]), ma2.columns, fontsize=18, rotation=45)
plt.yticks(range(ma2.shape[1]), ma2.columns, fontsize=18)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=18)
plt.title('Correlation Matrix dropout rate and %contribution of each sector', fontsize=16);

# %%
ma3
# Out:
#                 State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      Andhra Pradesh                 6.72                       5.20
# 1   Arunachal Pradesh                10.82                       6.71
# 2               Assam                15.36                      10.51
# 3               Bihar                  NaN                       4.08
# 4                 Goa                 0.73                       0.07
# 5             Gujarat                 0.89                       6.41
# 6             Haryana                 5.61                       5.81
# 7    Himachal Pradesh                 0.64                       0.87
# 8           Jharkhand                 5.48                       8.99
# 9           Karnataka                 2.02                       3.85
# 10             Kerala                  NaN                        NaN
# 11     Madhya Pradesh                 6.59                       9.20
# ...

# %%
ma3.drop(columns=['Gross State Domestic Product',"Per Capita GSDP (Rs.)",'pcp','tcp','scp'],axis=1,inplace=True)
ma3.set_index('State')
# Out:
#                    Primary - 2014-2015  Upper Primary - 2014-2015  \
# State
# Andhra Pradesh                    6.72                       5.20
# Arunachal Pradesh                10.82                       6.71
# Assam                            15.36                      10.51
# Bihar                              NaN                       4.08
# Goa                               0.73                       0.07
# Gujarat                           0.89                       6.41
# Haryana                           5.61                       5.81
# Himachal Pradesh                  0.64                       0.87
# Jharkhand                         5.48                       8.99
# Karnataka                         2.02                       3.85
# Kerala                             NaN                        NaN
# Madhya Pradesh                    6.59                       9.20
# Maharashtra                       1.26                       1.79
# ...

# %%
ma3.corr()
# Out:
#                               Primary - 2014-2015  Upper Primary - 2014-2015  \
# Primary - 2014-2015                      1.000000                   0.648542
# Upper Primary - 2014-2015                0.648542                   1.000000
# Secondary - 2014-2015                    0.167977                   0.515896
# Senior Secondary - 2014-2015             0.197693                  -0.017727
#
#                               Secondary - 2014-2015  \
# Primary - 2014-2015                        0.167977
# Upper Primary - 2014-2015                  0.515896
# Secondary - 2014-2015                      1.000000
# Senior Secondary - 2014-2015               0.057907
#
#                               Senior Secondary - 2014-2015
# Primary - 2014-2015                               0.197693
# Upper Primary - 2014-2015                        -0.017727
# Secondary - 2014-2015                             0.057907
# Senior Secondary - 2014-2015                      1.000000

# %%
plt.matshow(ma3.corr())
f = plt.figure(figsize=(29, 25))
plt.matshow(ma3.corr(), fignum=f.number)
plt.xticks(range(ma3.shape[1]), ma3.columns, fontsize=18, rotation=45)
plt.yticks(range(ma3.shape[1]), ma3.columns, fontsize=18)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=18)
plt.title('Correlation Matrix between dropout rates and population', fontsize=20);
